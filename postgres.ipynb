# %%
import psycopg2
import pandas as pd

# %%
conn = psycopg2.connect(dbname = "postgres",
                  user = "postgres",
                  password = "password",
                  host = "localhost",
                  port = "5432")

# %%
cursor = conn.cursor()

# %%
cursor.execute("SELECT * FROM city")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'A Corua (La Corua)', 87, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (2, 'Abha', 82, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (3, 'Abu Dhabi', 101, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (4, 'Acua', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (5, 'Adana', 97, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (6, 'Addis Abeba', 31, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (7, 'Aden', 107, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (8, 'Adoni', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (9, 'Ahmadnagar', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (10, 'Akishima', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (11, 'Akron', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (12, 'al-Ayn', 101, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (13, 'al-Hawiya', 82, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (14, 'al-Manama', 11, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (15, 'al-Qadarif', 89, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (16, 'al-Qatif', 82, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (17, 'Alessandria', 49, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (18, 'Allappuzha (Alleppey)', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (19, 'Allende', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (20, 'Almirante Brown', 6, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (21, 'Alvorada', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (22, 'Ambattur', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (23, 'Amersfoort', 67, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (24, 'Amroha', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (25, 'Angra dos Reis', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (26, 'Anpolis', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (27, 'Antofagasta', 22, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (28, 'Aparecida de Goinia', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (29, 'Apeldoorn', 67, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (30, 'Araatuba', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (31, 'Arak', 46, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (32, 'Arecibo', 77, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (33, 'Arlington', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (34, 'Ashdod', 48, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (35, 'Ashgabat', 98, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (36, 'Ashqelon', 48, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (37, 'Asuncin', 73, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (38, 'Athenai', 39, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (39, 'Atinsk', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (40, 'Atlixco', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (41, 'Augusta-Richmond County', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (42, 'Aurora', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (43, 'Avellaneda', 6, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (44, 'Bag', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (45, 'Baha Blanca', 6, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (46, 'Baicheng', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (47, 'Baiyin', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (48, 'Baku', 10, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (49, 'Balaiha', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (50, 'Balikesir', 97, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (51, 'Balurghat', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (52, 'Bamenda', 19, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (53, 'Bandar Seri Begawan', 16, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (54, 'Banjul', 37, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (55, 'Barcelona', 104, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (56, 'Basel', 91, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (57, 'Bat Yam', 48, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (58, 'Batman', 97, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (59, 'Batna', 2, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (60, 'Battambang', 18, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (61, 'Baybay', 75, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (62, 'Bayugan', 75, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (63, 'Bchar', 2, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (64, 'Beira', 63, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (65, 'Bellevue', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (66, 'Belm', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (67, 'Benguela', 4, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (68, 'Beni-Mellal', 62, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (69, 'Benin City', 69, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (70, 'Bergamo', 49, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (71, 'Berhampore (Baharampur)', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (72, 'Bern', 91, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (73, 'Bhavnagar', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (74, 'Bhilwara', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (75, 'Bhimavaram', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (76, 'Bhopal', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (77, 'Bhusawal', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (78, 'Bijapur', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (79, 'Bilbays', 29, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (80, 'Binzhou', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (81, 'Birgunj', 66, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (82, 'Bislig', 75, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (83, 'Blumenau', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (84, 'Boa Vista', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (85, 'Boksburg', 85, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (86, 'Botosani', 78, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (87, 'Botshabelo', 85, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (88, 'Bradford', 102, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (89, 'Braslia', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (90, 'Bratislava', 84, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (91, 'Brescia', 49, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (92, 'Brest', 34, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (93, 'Brindisi', 49, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (94, 'Brockton', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (95, 'Bucuresti', 78, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (96, 'Buenaventura', 24, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (97, 'Bydgoszcz', 76, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (98, 'Cabuyao', 75, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (99, 'Callao', 74, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (100, 'Cam Ranh', 105, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (101, 'Cape Coral', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (102, 'Caracas', 104, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (103, 'Carmen', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (104, 'Cavite', 75, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (105, 'Cayenne', 35, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (106, 'Celaya', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (107, 'Chandrapur', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (108, 'Changhwa', 92, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (109, 'Changzhou', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (110, 'Chapra', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (111, 'Charlotte Amalie', 106, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (112, 'Chatsworth', 85, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (113, 'Cheju', 86, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (114, 'Chiayi', 92, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (115, 'Chisinau', 61, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (116, 'Chungho', 92, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (117, 'Cianjur', 45, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (118, 'Ciomas', 45, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (119, 'Ciparay', 45, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (120, 'Citrus Heights', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (121, 'Citt del Vaticano', 41, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (122, 'Ciudad del Este', 73, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (123, 'Clarksville', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (124, 'Coacalco de Berriozbal', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (125, 'Coatzacoalcos', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (126, 'Compton', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (127, 'Coquimbo', 22, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (128, 'Crdoba', 6, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (129, 'Cuauhtmoc', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (130, 'Cuautla', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (131, 'Cuernavaca', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (132, 'Cuman', 104, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (133, 'Czestochowa', 76, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (134, 'Dadu', 72, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (135, 'Dallas', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (136, 'Datong', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (137, 'Daugavpils', 54, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (138, 'Davao', 75, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (139, 'Daxian', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (140, 'Dayton', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (141, 'Deba Habe', 69, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (142, 'Denizli', 97, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (143, 'Dhaka', 12, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (144, 'Dhule (Dhulia)', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (145, 'Dongying', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (146, 'Donostia-San Sebastin', 87, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (147, 'Dos Quebradas', 24, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (148, 'Duisburg', 38, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (149, 'Dundee', 102, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (150, 'Dzerzinsk', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (151, 'Ede', 67, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (152, 'Effon-Alaiye', 69, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (153, 'El Alto', 14, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (154, 'El Fuerte', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (155, 'El Monte', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (156, 'Elista', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (157, 'Emeishan', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (158, 'Emmen', 67, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (159, 'Enshi', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (160, 'Erlangen', 38, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (161, 'Escobar', 6, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (162, 'Esfahan', 46, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (163, 'Eskisehir', 97, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (164, 'Etawah', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (165, 'Ezeiza', 6, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (166, 'Ezhou', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (167, 'Faaa', 36, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (168, 'Fengshan', 92, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (169, 'Firozabad', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (170, 'Florencia', 24, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (171, 'Fontana', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (172, 'Fukuyama', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (173, 'Funafuti', 99, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (174, 'Fuyu', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (175, 'Fuzhou', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (176, 'Gandhinagar', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (177, 'Garden Grove', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (178, 'Garland', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (179, 'Gatineau', 20, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (180, 'Gaziantep', 97, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (181, 'Gijn', 87, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (182, 'Gingoog', 75, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (183, 'Goinia', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (184, 'Gorontalo', 45, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (185, 'Grand Prairie', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (186, 'Graz', 9, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (187, 'Greensboro', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (188, 'Guadalajara', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (189, 'Guaruj', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (190, 'guas Lindas de Gois', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (191, 'Gulbarga', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (192, 'Hagonoy', 75, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (193, 'Haining', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (194, 'Haiphong', 105, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (195, 'Haldia', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (196, 'Halifax', 20, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (197, 'Halisahar', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (198, 'Halle/Saale', 38, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (199, 'Hami', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (200, 'Hamilton', 68, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (201, 'Hanoi', 105, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (202, 'Hidalgo', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (203, 'Higashiosaka', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (204, 'Hino', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (205, 'Hiroshima', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (206, 'Hodeida', 107, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (207, 'Hohhot', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (208, 'Hoshiarpur', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (209, 'Hsichuh', 92, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (210, 'Huaian', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (211, 'Hubli-Dharwad', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (212, 'Huejutla de Reyes', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (213, 'Huixquilucan', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (214, 'Hunuco', 74, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (215, 'Ibirit', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (216, 'Idfu', 29, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (217, 'Ife', 69, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (218, 'Ikerre', 69, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (219, 'Iligan', 75, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (220, 'Ilorin', 69, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (221, 'Imus', 75, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (222, 'Inegl', 97, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (223, 'Ipoh', 59, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (224, 'Isesaki', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (225, 'Ivanovo', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (226, 'Iwaki', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (227, 'Iwakuni', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (228, 'Iwatsuki', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (229, 'Izumisano', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (230, 'Jaffna', 88, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (231, 'Jaipur', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (232, 'Jakarta', 45, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (233, 'Jalib al-Shuyukh', 53, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (234, 'Jamalpur', 12, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (235, 'Jaroslavl', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (236, 'Jastrzebie-Zdrj', 76, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (237, 'Jedda', 82, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (238, 'Jelets', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (239, 'Jhansi', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (240, 'Jinchang', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (241, 'Jining', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (242, 'Jinzhou', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (243, 'Jodhpur', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (244, 'Johannesburg', 85, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (245, 'Joliet', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (246, 'Jos Azueta', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (247, 'Juazeiro do Norte', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (248, 'Juiz de Fora', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (249, 'Junan', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (250, 'Jurez', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (251, 'Kabul', 1, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (252, 'Kaduna', 69, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (253, 'Kakamigahara', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (254, 'Kaliningrad', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (255, 'Kalisz', 76, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (256, 'Kamakura', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (257, 'Kamarhati', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (258, 'Kamjanets-Podilskyi', 100, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (259, 'Kamyin', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (260, 'Kanazawa', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (261, 'Kanchrapara', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (262, 'Kansas City', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (263, 'Karnal', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (264, 'Katihar', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (265, 'Kermanshah', 46, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (266, 'Kilis', 97, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (267, 'Kimberley', 85, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (268, 'Kimchon', 86, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (269, 'Kingstown', 81, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (270, 'Kirovo-Tepetsk', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (271, 'Kisumu', 52, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (272, 'Kitwe', 109, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (273, 'Klerksdorp', 85, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (274, 'Kolpino', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (275, 'Konotop', 100, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (276, 'Koriyama', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (277, 'Korla', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (278, 'Korolev', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (279, 'Kowloon and New Kowloon', 42, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (280, 'Kragujevac', 108, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (281, 'Ktahya', 97, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (282, 'Kuching', 59, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (283, 'Kumbakonam', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (284, 'Kurashiki', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (285, 'Kurgan', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (286, 'Kursk', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (287, 'Kuwana', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (288, 'La Paz', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (289, 'La Plata', 6, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (290, 'La Romana', 27, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (291, 'Laiwu', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (292, 'Lancaster', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (293, 'Laohekou', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (294, 'Lapu-Lapu', 75, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (295, 'Laredo', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (296, 'Lausanne', 91, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (297, 'Le Mans', 34, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (298, 'Lengshuijiang', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (299, 'Leshan', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (300, 'Lethbridge', 20, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (301, 'Lhokseumawe', 45, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (302, 'Liaocheng', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (303, 'Liepaja', 54, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (304, 'Lilongwe', 58, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (305, 'Lima', 74, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (306, 'Lincoln', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (307, 'Linz', 9, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (308, 'Lipetsk', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (309, 'Livorno', 49, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (310, 'Ljubertsy', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (311, 'Loja', 28, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (312, 'London', 102, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (313, 'London', 20, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (314, 'Lublin', 76, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (315, 'Lubumbashi', 25, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (316, 'Lungtan', 92, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (317, 'Luzinia', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (318, 'Madiun', 45, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (319, 'Mahajanga', 57, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (320, 'Maikop', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (321, 'Malm', 90, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (322, 'Manchester', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (323, 'Mandaluyong', 75, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (324, 'Mandi Bahauddin', 72, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (325, 'Mannheim', 38, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (326, 'Maracabo', 104, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (327, 'Mardan', 72, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (328, 'Maring', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (329, 'Masqat', 71, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (330, 'Matamoros', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (331, 'Matsue', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (332, 'Meixian', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (333, 'Memphis', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (334, 'Merlo', 6, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (335, 'Mexicali', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (336, 'Miraj', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (337, 'Mit Ghamr', 29, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (338, 'Miyakonojo', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (339, 'Mogiljov', 13, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (340, 'Molodetno', 13, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (341, 'Monclova', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (342, 'Monywa', 64, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (343, 'Moscow', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (344, 'Mosul', 47, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (345, 'Mukateve', 100, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (346, 'Munger (Monghyr)', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (347, 'Mwanza', 93, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (348, 'Mwene-Ditu', 25, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (349, 'Myingyan', 64, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (350, 'Mysore', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (351, 'Naala-Porto', 63, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (352, 'Nabereznyje Telny', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (353, 'Nador', 62, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (354, 'Nagaon', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (355, 'Nagareyama', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (356, 'Najafabad', 46, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (357, 'Naju', 86, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (358, 'Nakhon Sawan', 94, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (359, 'Nam Dinh', 105, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (360, 'Namibe', 4, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (361, 'Nantou', 92, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (362, 'Nanyang', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (363, 'NDjamna', 21, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (364, 'Newcastle', 85, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (365, 'Nezahualcyotl', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (366, 'Nha Trang', 105, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (367, 'Niznekamsk', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (368, 'Novi Sad', 108, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (369, 'Novoterkassk', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (370, 'Nukualofa', 95, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (371, 'Nuuk', 40, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (372, 'Nyeri', 52, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (373, 'Ocumare del Tuy', 104, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (374, 'Ogbomosho', 69, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (375, 'Okara', 72, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (376, 'Okayama', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (377, 'Okinawa', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (378, 'Olomouc', 26, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (379, 'Omdurman', 89, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (380, 'Omiya', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (381, 'Ondo', 69, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (382, 'Onomichi', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (383, 'Oshawa', 20, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (384, 'Osmaniye', 97, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (385, 'ostka', 100, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (386, 'Otsu', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (387, 'Oulu', 33, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (388, 'Ourense (Orense)', 87, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (389, 'Owo', 69, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (390, 'Oyo', 69, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (391, 'Ozamis', 75, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (392, 'Paarl', 85, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (393, 'Pachuca de Soto', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (394, 'Pak Kret', 94, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (395, 'Palghat (Palakkad)', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (396, 'Pangkal Pinang', 45, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (397, 'Papeete', 36, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (398, 'Parbhani', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (399, 'Pathankot', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (400, 'Patiala', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (401, 'Patras', 39, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (402, 'Pavlodar', 51, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (403, 'Pemalang', 45, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (404, 'Peoria', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (405, 'Pereira', 24, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (406, 'Phnom Penh', 18, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (407, 'Pingxiang', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (408, 'Pjatigorsk', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (409, 'Plock', 76, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (410, 'Po', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (411, 'Ponce', 77, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (412, 'Pontianak', 45, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (413, 'Poos de Caldas', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (414, 'Portoviejo', 28, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (415, 'Probolinggo', 45, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (416, 'Pudukkottai', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (417, 'Pune', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (418, 'Purnea (Purnia)', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (419, 'Purwakarta', 45, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (420, 'Pyongyang', 70, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (421, 'Qalyub', 29, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (422, 'Qinhuangdao', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (423, 'Qomsheh', 46, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (424, 'Quilmes', 6, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (425, 'Rae Bareli', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (426, 'Rajkot', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (427, 'Rampur', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (428, 'Rancagua', 22, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (429, 'Ranchi', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (430, 'Richmond Hill', 20, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (431, 'Rio Claro', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (432, 'Rizhao', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (433, 'Roanoke', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (434, 'Robamba', 28, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (435, 'Rockford', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (436, 'Ruse', 17, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (437, 'Rustenburg', 85, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (438, 's-Hertogenbosch', 67, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (439, 'Saarbrcken', 38, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (440, 'Sagamihara', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (441, 'Saint Louis', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (442, 'Saint-Denis', 79, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (443, 'Sal', 62, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (444, 'Salala', 71, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (445, 'Salamanca', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (446, 'Salinas', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (447, 'Salzburg', 9, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (448, 'Sambhal', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (449, 'San Bernardino', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (450, 'San Felipe de Puerto Plata', 27, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (451, 'San Felipe del Progreso', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (452, 'San Juan Bautista Tuxtepec', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (453, 'San Lorenzo', 73, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (454, 'San Miguel de Tucumn', 6, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (455, 'Sanaa', 107, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (456, 'Santa Brbara dOeste', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (457, 'Santa F', 6, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (458, 'Santa Rosa', 75, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (459, 'Santiago de Compostela', 87, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (460, 'Santiago de los Caballeros', 27, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (461, 'Santo Andr', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (462, 'Sanya', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (463, 'Sasebo', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (464, 'Satna', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (465, 'Sawhaj', 29, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (466, 'Serpuhov', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (467, 'Shahr-e Kord', 46, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (468, 'Shanwei', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (469, 'Shaoguan', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (470, 'Sharja', 101, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (471, 'Shenzhen', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (472, 'Shikarpur', 72, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (473, 'Shimoga', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (474, 'Shimonoseki', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (475, 'Shivapuri', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (476, 'Shubra al-Khayma', 29, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (477, 'Siegen', 38, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (478, 'Siliguri (Shiliguri)', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (479, 'Simferopol', 100, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (480, 'Sincelejo', 24, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (481, 'Sirjan', 46, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (482, 'Sivas', 97, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (483, 'Skikda', 2, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (484, 'Smolensk', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (485, 'So Bernardo do Campo', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (486, 'So Leopoldo', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (487, 'Sogamoso', 24, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (488, 'Sokoto', 69, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (489, 'Songkhla', 94, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (490, 'Sorocaba', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (491, 'Soshanguve', 85, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (492, 'Sousse', 96, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (493, 'South Hill', 5, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (494, 'Southampton', 102, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (495, 'Southend-on-Sea', 102, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (496, 'Southport', 102, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (497, 'Springs', 85, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (498, 'Stara Zagora', 17, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (499, 'Sterling Heights', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (500, 'Stockport', 102, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (501, 'Sucre', 14, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (502, 'Suihua', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (503, 'Sullana', 74, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (504, 'Sultanbeyli', 97, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (505, 'Sumqayit', 10, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (506, 'Sumy', 100, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (507, 'Sungai Petani', 59, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (508, 'Sunnyvale', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (509, 'Surakarta', 45, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (510, 'Syktyvkar', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (511, 'Syrakusa', 49, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (512, 'Szkesfehrvr', 43, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (513, 'Tabora', 93, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (514, 'Tabriz', 46, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (515, 'Tabuk', 82, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (516, 'Tafuna', 3, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (517, 'Taguig', 75, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (518, 'Taizz', 107, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (519, 'Talavera', 75, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (520, 'Tallahassee', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (521, 'Tama', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (522, 'Tambaram', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (523, 'Tanauan', 75, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (524, 'Tandil', 6, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (525, 'Tangail', 12, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (526, 'Tanshui', 92, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (527, 'Tanza', 75, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (528, 'Tarlac', 75, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (529, 'Tarsus', 97, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (530, 'Tartu', 30, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (531, 'Teboksary', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (532, 'Tegal', 45, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (533, 'Tel Aviv-Jaffa', 48, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (534, 'Tete', 63, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (535, 'Tianjin', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (536, 'Tiefa', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (537, 'Tieli', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (538, 'Tokat', 97, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (539, 'Tonghae', 86, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (540, 'Tongliao', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (541, 'Torren', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (542, 'Touliu', 92, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (543, 'Toulon', 34, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (544, 'Toulouse', 34, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (545, 'Trshavn', 32, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (546, 'Tsaotun', 92, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (547, 'Tsuyama', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (548, 'Tuguegarao', 75, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (549, 'Tychy', 76, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (550, 'Udaipur', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (551, 'Udine', 49, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (552, 'Ueda', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (553, 'Uijongbu', 86, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (554, 'Uluberia', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (555, 'Urawa', 50, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (556, 'Uruapan', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (557, 'Usak', 97, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (558, 'Usolje-Sibirskoje', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (559, 'Uttarpara-Kotrung', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (560, 'Vaduz', 55, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (561, 'Valencia', 104, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (562, 'Valle de la Pascua', 104, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (563, 'Valle de Santiago', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (564, 'Valparai', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (565, 'Vancouver', 20, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (566, 'Varanasi (Benares)', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (567, 'Vicente Lpez', 6, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (568, 'Vijayawada', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (569, 'Vila Velha', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (570, 'Vilnius', 56, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (571, 'Vinh', 105, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (572, 'Vitria de Santo Anto', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (573, 'Warren', 103, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (574, 'Weifang', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (575, 'Witten', 38, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (576, 'Woodridge', 8, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (577, 'Wroclaw', 76, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (578, 'Xiangfan', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (579, 'Xiangtan', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (580, 'Xintai', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (581, 'Xinxiang', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (582, 'Yamuna Nagar', 44, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (583, 'Yangor', 65, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (584, 'Yantai', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (585, 'Yaound', 19, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (586, 'Yerevan', 7, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (587, 'Yinchuan', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (588, 'Yingkou', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (589, 'York', 102, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (590, 'Yuncheng', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (591, 'Yuzhou', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (592, 'Zalantun', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (593, 'Zanzibar', 93, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (594, 'Zaoyang', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (595, 'Zapopan', 60, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (596, 'Zaria', 69, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (597, 'Zeleznogorsk', 80, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (598, 'Zhezqazghan', 51, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (599, 'Zhoushan', 23, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))
# (600, 'Ziguinchor', 83, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))

# %%
data = pd.DataFrame(rows)
data.columns = ["city_id","city","country_id","last_update"]

# %%
cursor.execute("SELECT * FROM city WHERE city_id = %s", (44,))
rows = cursor.fetchall()

# %%
print(rows)
# Out:
# [(44, 'Bag', 15, datetime.datetime(2022, 2, 15, 9, 45, 25, tzinfo=datetime.timezone.utc))]
